# %%
using Pkg
Pkg.activate(".")
Pkg.instantiate()
# Out:
#  Activating environment at `~/Research/ICRA2020_fast_mpc_in_altro/benchmarks/random_linear_mpc/Project.toml`

# %% [markdown]
# # Generate Random Problem

# %%
include("random_linear.jl")

# using ControlSystems

n = 12
m = Int(n/2)
N = 10
A,B = gendiscrete(n,m)

Q = Diagonal(10*rand(n))
R = Diagonal(0.1*ones(m))

Qf = Q #dare(A, B, Q, R)

x̄ = rand(n) .+ 1
ū = 0.1*rand(m)
x0 = (rand(n) .- 1) .* x̄ * 0.5
xf = zeros(n)

nothing

# %% [markdown]
# # Solve Using Altro

# %%
using Altro
using TrajectoryOptimization
using RobotDynamics

const RD = RobotDynamics

dt = 0.1 # doesn't matter, just needs to be non-zero
model = RD.LinearModel(A, B; dt=dt)
objective = LQRObjective(Q, R, Qf, xf, N)

constraints = ConstraintList(n, m, N)
bound = BoundConstraint(n, m, x_min=-x̄, x_max=x̄, u_min=-ū, u_max=ū)
add_constraint!(constraints, bound, 1:N)

tf = (N-1)*dt

problem = Problem(model, objective, xf, tf, x0=x0, integration=RD.PassThrough)
solver = ALTROSolver(problem)
set_options!(solver)
solve!(solver)

b = benchmark_solve!(solver)

@show maximum(b)
@show max_violation(solver)
@show cost(solver)

X = states(solver)
U = controls(solver)
# Out:
# maximum(b) = TrialEstimate(177.875 μs)
# max_violation(solver) = 0.0
# cost(solver) = 0.8995631243068232
# 9-element Array{StaticArrays.SArray{Tuple{6},Float64,1,6},1}:
#  [-0.1410036352621738, -3.930538352997404e-5, -0.3207503374464488, -0.037171243464140996, -0.006965951687226294, 0.07245668901837964]
#  [0.1711806742879054, 0.034938318712652704, 0.11651583386373048, -0.10123369195377545, 0.003913674292216102, -0.15302664124216636]
#  [0.0625182081740592, -0.002092076876457953, 0.0905329095548872, 0.029880961768342977, -0.08945669206454764, -0.019216492826922997]
#  [0.05428625349864169, -0.006062094020775005, -0.004059156997491685, -0.05384559380087755, 0.02331726216164038, -0.01700349071311058]
#  [0.028306990337782754, 0.005493196120942705, 0.0470161534319891, 0.015712157707226223, -0.03758886638645406, -0.01880931743210535]
#  [0.021635074174500817, -0.005564101728631963, -0.0038868117825855953, -0.021505655348259774, 0.009304948009807964, -0.0028133406459283634]
#  [0.010964394740126001, 0.0035628707459603756, 0.017392159512542676, 0.005310439716913158, -0.012997381766763273, -0.008141122764086937]
#  [0.009626070177733308, -0.0026803272995567355, -0.0014682295432266667, -0.009635667566516307, 0.00350564267064435, 0.0008636333002738737]
#  [0.00510960964646308, -0.00029820654653650233, 0.0008241967502148817, -0.002030155020170596, -7.770534376660693e-5, -0.0014294920757124826]

# %% [markdown]
# # Solve Using OSQP

# %%
using JuMP
using OSQP
using BenchmarkTools

select(i, n) = (n*(i-1)+1):(n*(i-1)+n)

jump_model = Model(OSQP.Optimizer)
set_silent(jump_model)

@variable(jump_model, x[1:((N)*n)])
@variable(jump_model, u[1:((N-1)*n)])

objective_exp = @expression(jump_model, 0.5*transpose(x[select(N, n)]) * Qf * x[select(N, n)])

@constraint(jump_model, x[select(1, n)] .== x0)

for i=1:N-1
    # dynamics constraints
    @constraint(jump_model, A*x[select(i, n)] + B*u[select(i, m)] .== x[select(i+1, n)])

    # stagewise state cost
    add_to_expression!(objective_exp, 0.5*transpose(x[select(i, n)]) * Q * x[select(i, n)])

    # stagewise control cost
    add_to_expression!(objective_exp, 0.5*transpose(u[select(i, m)]) * R * u[select(i, m)])

    # control/state bound constraints
    @constraint(jump_model, x[select(i, n)] .<= x̄)
    @constraint(jump_model, x[select(i, n)] .>= -x̄)
    @constraint(jump_model, u[select(i, m)] .<= ū)
    @constraint(jump_model, u[select(i, m)] .>= -ū)
end

@objective(jump_model, Min, objective_exp)

optimize!(jump_model)

set_start_value.(x, value.(x))

X_osqp = [value.(x)[select(i, n)] for i=1:N]
U_osqp = [value.(u)[select(i, m)] for i=1:N-1]

@show objective_value(jump_model)

@benchmark optimize!($jump_model) samples=10 evals=10
# Out:
# objective_value(jump_model) = 10.77747079337081
# BenchmarkTools.Trial:
#   memory estimate:  32 bytes
#   allocs estimate:  2
#   --------------
#   minimum time:     414.050 μs (0.00% GC)
#   median time:      425.137 μs (0.00% GC)
#   mean time:        438.115 μs (0.00% GC)
#   maximum time:     524.170 μs (0.00% GC)
#   --------------
#   samples:          10
#   evals/sample:     10

# %%
@assert X[1] ≈ x0
@assert value.(x)[select(1, n)] ≈ x0

# %%
using Plots

u_vals = [U[i][1] for i=1:N-1]
u_vals_osqp = [U_osqp[i][1] for i=1:N-1]

plot(1:N-1, u_vals, seriestype=:bar)
plot!(1:N-1, u_vals_osqp, seriestype=:bar)

# %%
objective_value_(X, U) = sum([0.5*X[i]'*Q*X[i] for i=1:N]) + sum([0.5*U[i]'*R*U[i] for i=1:N-1])

@show objective_value_(X, U)
@show objective_value_(X_osqp, U_osqp)
# Out:
# MethodError: no method matching *(::Adjoint{Float64,StaticArrays.SArray{Tuple{12},Float64,1,12}}, ::Adjoint{Float64,StaticArrays.SArray{Tuple{12},Float64,1,12}})
# Closest candidates are:
#   *(::Adjoint{T,#s664} where #s664<:(AbstractArray{T,1} where T) where T, ::Adjoint{T,#s664} where #s664<:(AbstractArray{T,1} where T) where T) at /Users/julia/buildbot/worker/package_macos64/build/usr/share/julia/stdlib/v1.4/LinearAlgebra/src/adjtrans.jl:256
#   *(::Adjoint{T,#s664} where #s664<:(AbstractArray{T,1} where T) where T, ::AbstractArray{T,2} where T) at /Users/julia/buildbot/worker/package_macos64/build/usr/share/julia/stdlib/v1.4/LinearAlgebra/src/matmul.jl:133
#   *(::AbstractArray{T,2} where T, ::AbstractArray{T,2} where T) at /Users/julia/buildbot/worker/package_macos64/build/usr/share/julia/stdlib/v1.4/LinearAlgebra/src/matmul.jl:152
#   ...
#
# Stacktrace:
#  [1] *(::Adjoint{Float64,StaticArrays.SArray{Tuple{12},Float64,1,12}}, ::Adjoint{Float64,StaticArrays.SArray{Tuple{12},Float64,1,12}}) at /Users/julia/buildbot/worker/package_macos64/build/usr/share/julia/stdlib/v1.4/LinearAlgebra/src/adjtrans.jl:256
#  [2] afoldl(::typeof(*), ::Adjoint{Float64,StaticArrays.SArray{Tuple{12},Float64,1,12}}, ::Adjoint{Float64,StaticArrays.SArray{Tuple{12},Float64,1,12}}) at ./operators.jl:516
#  [3] * at ./operators.jl:529 [inlined]
#  [4] (::var"#37#39"{Array{StaticArrays.SArray{Tuple{12},Float64,1,12},1}})(::Int64) at ./none:0
#  [5] iterate at ./generator.jl:47 [inlined]
#  [6] collect(::Base.Generator{UnitRange{Int64},var"#37#39"{Array{StaticArrays.SArray{Tuple{12},Float64,1,12},1}}}) at ./array.jl:665
#  [7] objective_value_(::Array{StaticArrays.SArray{Tuple{12},Float64,1,12},1}, ::Array{StaticArrays.SArray{Tuple{6},Float64,1,6},1}) at ./In[11]:1
#  [8] top-level scope at show.jl:613
#  [9] top-level scope at In[11]:2
